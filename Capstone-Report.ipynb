# %% [markdown]
# <h1 align=center><font size = 5>Comparing Neighborhoods of Newton, MA</font></h1>

# %% [markdown]
# # 1. Purpose & Introduction
#
# This notebook provides a comparison between the different neighborhoods (also known as villages) in the city of Newton, MA. The comparison is used to help  families who want to move to Newton to choose a neighborhood that is best suited for their needs. Generally, a family will want to look at what different neighborhoods have to offer. For example, they may want to be close to public transit, they may want to have play grounds nearby if they have little kids. A couple without kids may want to have access to a lot of restaurants. A family also will consider housing price if they want to buy a house. They will also want to know the crime data of different neighborhoods.

# %% [markdown]
# # 2. Data Source and Description

# %% [markdown]
# The data of interest for a family include nearby amenities/venues (data can be obtained from Foursquare) and housing prices, which will be obtained from the website Redfin, which has a lot of data on sold house prices. The crime data of the city will be obtained as well.
#
# There will be three different types of data used for this problem.
#
# 1. Venues Data from Foursquare
# 2. Housing Data (prices sold in the last three year) from Redfin
# 3. Crime incident data from Newton Police data log (see "http://www.newtonpolice.com/POLICE_LOG/CURRENT/20180101.txt" for example)
#
# The venues data from Foursquare will be obtained to determine the top venues in a neighborhood and group neighborhood into clusters. This data will help a family to see if the amenities in that neighborhood meet their needs.
#
# The house price data will help a family to determine if they can afford a house of interest in such neighborhood as well as to compare different neighborhoods in the same cluster.
#
# The crime data help a family to compare different villages.

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# There are three main steps in solving this problem.
#
# 1. Step 1: Using Fourquare venues data to divide the different villages into clusters. This allows a family to easily identify neighborhoods that are similar. This is done by k-means clustering. The number of cluster is limited to 3 because there is only 11 neighborhoods in Newton.
# 2. Step 2: Calculate average house price (actual price as well as $ per square feet) for each zip code based on house data in the last three years. Here, we use boxplots to compare the different neighborhoods.
# 3. Step 3: Calculate/count the total number of police incident report for each zip code. Bar graph is a good used for this comparison.
#
# From the above three set of data, a family can then easily look at the different clusters and compare the house price as well as crime rate. Based on what is most important to the family and what they think they can afford, they can easily choose the most appropriate village.
#
# Data Exploration:
#
# For Foursquare data, the radius from the center of the zip code was varied a little bit to ensure there is sufficient number of venues for each villages.
#
# For housing data, initially, all sold houses information were obtained. However, it was realized that does not provide a good estimate of housing data for a family. A family typically knows what types of house they want to consider purchasing and the price range. Therefore, for the purpose of this project, only housing data for single house or town house with at least 3 bedrooms and at least two bath rooms were considered. ALso, the price range was limited between 400K to 1M dollars.
#
# The crime data from Newton police log do not have all the information needed, especially the zip code. Also, the exact address is not always provided. There is no explanation of the abbreviation. Therefore, it was decided that we can only count on the number incident reports and cannot differentiate any further for crime data. Also, to get zip code from addresses in the police log, it had to be done in batch mode (~500 call at a time) due to Nominatum server limit.

# %% [markdown]
# ## 4. Results

# %% [markdown]
# ### 4.1 Identification of the villages

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# Using the geojson file from Newton, MA git hub, the following villages were identified.

# %%
from IPython.display import Image
Image('village list.JPG')

# %% [markdown]
# Graphically, they are shown below

# %%
Image('neighborhoodmap.JPG')

# %% [markdown]
# ### 4.2 Foursquare Clustering

# %% [markdown]
# The data from Foursquare and after some clustering using K-means, the following clusters were identified.

# %%
Image('cluster1.JPG')

# %%
Image('cluster2.JPG')

# %%
Image('cluster3.JPG')

# %% [markdown]
# The different clusters are shown in the graph below

# %%
Image('clustermap.JPG')

# %% [markdown]
# ### 4.2 Housing Data Results

# %% [markdown]
# Redfin was used to obtained data on houses that were sold in the last three years. The comparison of house price are shown below. An example of data frame for housing price, after cleaning up, is below

# %%
Image('housedf.JPG')

# %%
Image('housepricezipcode1.JPG')

# %%
Image('housepricezipcode2.JPG')

# %% [markdown]
# From the above data, it shows that there is much larger number of police incident reports in zip code 02459, 02465, and 02458 compared to the rest of the other zip codes.

# %% [markdown]
# ### 4.3 Summary of all Results

# %% [markdown]
# Summary of different data for all villages. The cluster information is shown.

# %%
Image('finalresults.JPG')

# %% [markdown]
# Visually, the comparison different villages are shown below

# %%
Image('housecluster1.JPG')

# %%
Image('housecluster2.JPG')

# %%
Image('crimeresults.JPG')

# %% [markdown]
# ## 5. Observations

# %% [markdown]
# There are three clusters for the 10 different villages. Newton Center is a cluster on its own with top venues including mostly restaurants and coffee shop. This would be an ideal location for a family that likes to eat out often. The second cluster includes Brighton, Newton Lower Falls, and Newton Highlands. The most common venue of these three villages include pizza, donut shop and coffee. This location would probably be ideal for family without kids. The last cluster, which includes the rest of the villages, has park, gym, dance studio, ice cream shop, music stores, playground, baseball field, and pet stores in their top ten common venues. These villages are probably most appropriate for family with little kids.
#
# In terms of average house price, Newton Upper Falls (02464) has the lowest average home price for the last 3 years. However, in terms of price per square feet, Brighton (02135) has the lowest value.
#
# From crime data, it shows that there is much larger number of police incident reports in zip code 02459, 02465, and 02458 compared to the rest of the other zip codes.

# %% [markdown]
# ## 6. Recommendations

# %% [markdown]
# From the data above, a family can compare different neighborhoods in the same cluster. For example, cluster 1 has three zip codes (02135, 02462 and 02461). Of the three, zip code 02135 has the cheapest house as well as the lowest number of police incident reports.  If a family wants affordable housing, this may be the best zip code in Newton.
#
# This project focused mostly on the city of Newton, M. This can be easily repeated for other cities and/or comparison of different neighborhoods in different cities. The main challenges is the ability to obtain consistent crime data, which can vary from city to city.
